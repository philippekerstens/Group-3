# %%
# Before beginning this notebook you will need to add the following code to the query tool in pgAdmin: 
# ALTER TABLE counties ADD PRIMARY KEY (fips_date); ALTER TABLE hospitals ADD PRIMARY KEY (fips_date);
# Additionally, you will need to enter your password into the connection_string variable in the config.py file. 
# The place holder text is YOURPASSWORDHERE

# %%
# Import dependencies
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
from config import connection_string
import pandas as pd
import psycopg2 as pg
from flask import Flask, jsonify, render_template
from functools import reduce

# %%
 # Create engine using the database file
engine = sqlalchemy.create_engine(connection_string)

# %%
# Reflect an existing databade into a new model
Base = automap_base()

# %%
# Reflect the tables
Base.prepare(engine, reflect=True)

# %%
dbConnection = engine.connect();

# %%
# Save references to each table
Counties = Base.classes.counties
Hospitals = Base.classes.hospitals
Vaccinations = Base.classes.vaccinations

# %%
Base.classes.keys()
# Out:
# ['counties', 'hospitals', 'vaccinations']

# %%
merged_df = pd.read_sql("SELECT * FROM counties INNER JOIN hospitals ON counties.fips_date = hospitals.fips_date", dbConnection);

# %%
merged_df.head()
# Out:
#    index  cases_to_date  deaths_to_date       fips_date  index fips_code  \
# 0     21          26881             314  10012020-12-25     21      1001
# 1     24          34774             382  10012021-01-15     24      1001
# 2     25          36617             397  10012021-01-22     25      1001
# 3     31          44055             639  10012021-03-05     31      1001
# 4     33          45263             672  10012021-03-19     33      1001
#
#   collection_week  total_beds_7_day_sum  all_adult_hospital_beds_7_day_sum  \
# 0      2020-12-25                   581                                581
# 1      2021-01-15                   602                                602
# 2      2021-01-22                   602                                602
# 3      2021-03-05                   602                                602
# 4      2021-03-19                   602                                602
#
#    all_adult_hospital_inpatient_beds_7_day_sum  ...  \
# 0                                          462  ...
# 1                                          462  ...
# 2                                          462  ...
# 3                                          462  ...
# 4                                          462  ...
#
#    total_ped_patients_hospitalized_con_and_sus_covid_7_day_sum  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    total_ped_patients_hospitalized_con_covid_7_day_sum  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    inpatient_beds_7_day_sum  total_icu_beds_7_day_sum  \
# 0                       462                        42
# 1                       462                        42
# 2                       462                        42
# 3                       462                        42
# 4                       462                        42
#
#    total_staffed_adult_icu_beds_7_day_sum  icu_beds_used_7_day_sum  \
# 0                                      42                       42
# 1                                      42                       42
# 2                                      42                       42
# 3                                      42                       40
# 4                                      42                       33
#
#    staffed_adult_icu_bed_occupancy_7_day_sum  \
# 0                                         42
# 1                                         42
# 2                                         42
# 3                                         40
# 4                                         33
#
#    staffed_icu_adult_patients_con_and_sus_covid_7_day_sum  \
# 0                                                 27
# 1                                                 39
# 2                                                 41
# 3                                                 22
# 4                                                  9
#
#    staffed_icu_adult_patients_con_covid_7_day_sum       fips_date
# 0                                              27  10012020-12-25
# 1                                              39  10012021-01-15
# 2                                              40  10012021-01-22
# 3                                              22  10012021-03-05
# 4                                               9  10012021-03-19
#
# [5 rows x 24 columns]

# %%
#fips_date = merged_df['fips_date']
#merged_df.drop('fips_date', axis=1, inplace=True)
#merged_df['fips_date'] = fips_date
#fips_date
merged_df.drop(columns={merged_df.columns[3]}, inplace=True)
merged_df
# Out:
#          index  cases_to_date  deaths_to_date   index fips_code  \
# 0           21          26881             314      21      1001
# 1           24          34774             382      24      1001
# 2           25          36617             397      25      1001
# 3           31          44055             639      31      1001
# 4           33          45263             672      33      1001
# ...        ...            ...             ...     ...       ...
# 110337  208898           1738               7  159852     78020
# 110338  208902           1772               7  159856     78020
# 110339  208911           2242              21  159865     78020
# 110340  208912           2258              21  159866     78020
# 110341  208915           2317              21  159869     78020
#
#        collection_week  total_beds_7_day_sum  \
# 0           2020-12-25                   581
# 1           2021-01-15                   602
# 2           2021-01-22                   602
# 3           2021-03-05                   602
# 4           2021-03-19                   602
# ...                ...                   ...
# 110337      2021-06-18                   924
# 110338      2021-07-16                   924
# 110339      2021-09-17                   924
# 110340      2021-09-24                   924
# 110341      2021-10-15                   924
#
#         all_adult_hospital_beds_7_day_sum  \
# 0                                     581
# 1                                     602
# 2                                     602
# 3                                     602
# 4                                     602
# ...                                   ...
# 110337                                868
# 110338                                868
# 110339                                868
# 110340                                868
# 110341                                868
#
#         all_adult_hospital_inpatient_beds_7_day_sum  \
# 0                                               462
# 1                                               462
# 2                                               462
# 3                                               462
# 4                                               462
# ...                                             ...
# 110337                                          728
# 110338                                          728
# 110339                                          728
# 110340                                          728
# 110341                                          728
#
#         inpatient_beds_used_7_day_sum  ...  \
# 0                                 445  ...
# 1                                 423  ...
# 2                                 360  ...
# 3                                 315  ...
# 4                                 284  ...
# ...                               ...  ...
# 110337                            387  ...
# 110338                            486  ...
# 110339                            475  ...
# 110340                            410  ...
# 110341                            402  ...
#
#         total_adult_patients_hospitalized_con_covid_7_day_sum  \
# 0                                                     281
# 1                                                     247
# 2                                                     149
# 3                                                      76
# 4                                                      43
# ...                                                   ...
# 110337                                                 11
# 110338                                                 69
# 110339                                                  7
# 110340                                                 20
# 110341                                                  7
#
#         total_ped_patients_hospitalized_con_and_sus_covid_7_day_sum  \
# 0                                                       0
# 1                                                       0
# 2                                                       0
# 3                                                       0
# 4                                                       0
# ...                                                   ...
# 110337                                                  0
# 110338                                                  0
# 110339                                                  0
# 110340                                                  0
# 110341                                                  0
#
#         total_ped_patients_hospitalized_con_covid_7_day_sum  \
# 0                                                       0
# 1                                                       0
# 2                                                       0
# 3                                                       0
# 4                                                       0
# ...                                                   ...
# 110337                                                  0
# 110338                                                  0
# 110339                                                  0
# 110340                                                  0
# 110341                                                  0
#
#         inpatient_beds_7_day_sum  total_icu_beds_7_day_sum  \
# 0                            462                        42
# 1                            462                        42
# 2                            462                        42
# 3                            462                        42
# 4                            462                        42
# ...                          ...                       ...
# 110337                       784                        56
# 110338                       784                        56
# 110339                       784                        56
# 110340                       784                        56
# 110341                       784                        56
#
#         total_staffed_adult_icu_beds_7_day_sum  icu_beds_used_7_day_sum  \
# 0                                           42                       42
# 1                                           42                       42
# 2                                           42                       42
# 3                                           42                       40
# 4                                           42                       33
# ...                                        ...                      ...
# 110337                                      56                       45
# 110338                                      56                       35
# 110339                                      56                       54
# 110340                                      56                       29
# 110341                                      56                       40
#
#         staffed_adult_icu_bed_occupancy_7_day_sum  \
# 0                                              42
# 1                                              42
# 2                                              42
# 3                                              40
# 4                                              33
# ...                                           ...
# 110337                                         45
# 110338                                         35
# 110339                                         54
# 110340                                         29
# 110341                                         40
#
#         staffed_icu_adult_patients_con_and_sus_covid_7_day_sum  \
# 0                                                      27
# 1                                                      39
# 2                                                      41
# 3                                                      22
# 4                                                       9
# ...                                                   ...
# 110337                                                  0
# 110338                                                 14
# 110339                                                  0
# 110340                                                  7
# 110341                                                  7
#
#         staffed_icu_adult_patients_con_covid_7_day_sum
# 0                                                   27
# 1                                                   39
# 2                                                   40
# 3                                                   22
# 4                                                    9
# ...                                                ...
# 110337                                               0
# 110338                                              14
# 110339                                               0
# 110340                                               7
# 110341                                               7
#
# [110342 rows x 22 columns]

# %%
vax_df = pd.read_sql("SELECT * FROM vaccinations", dbConnection);
hospital_df = pd.read_sql("SELECT * FROM hospitals", dbConnection);
cases_df = pd.read_sql("SELECT * FROM counties", dbConnection);

# %%
dfs = [vax_df, hospital_df, cases_df]

# %%
df_final = reduce(lambda left,right: pd.merge(left,right,on='fips_date'), dfs)

# %%
df_final.head()
# Out:
#    index_x  Series_Complete_Pop_Pct  Series_Complete_Yes  \
# 0    49245                     38.0                17795
# 1    49246                     46.2                55067
# 2    49247                     39.7                 4162
# 3    49248                     43.5                13103
# 4    49251                     52.8                68276
#
#    Series_Complete_18Plus  Series_Complete_18PlusPop_Pct  \
# 0                   17728                           54.4
# 1                   52271                           57.5
# 2                    4059                           48.3
# 3                   12477                           51.2
# 4                   65043                           62.0
#
#    Series_Complete_65Plus  Series_Complete_65PlusPop_Pct  Completeness_pct  \
# 0                    5292                           78.0              97.6
# 1                   15433                           82.9              99.1
# 2                    1756                           70.7              99.1
# 3                    4617                           67.9              83.0
# 4                   21163                           87.2              97.9
#
#    Administered_Dose1_Pop_Pct  Administered_Dose1_Recip_18PlusPop_Pct  ...  \
# 0                        42.6                                    60.8  ...
# 1                        52.1                                    64.7  ...
# 2                        43.4                                    52.6  ...
# 3                        50.1                                    58.9  ...
# 4                        59.1                                    69.1  ...
#
#    inpatient_beds_7_day_sum total_icu_beds_7_day_sum  \
# 0                       203                       35
# 1                      4066                      308
# 2                       151                        0
# 3                       114                       12
# 4                      3367                      728
#
#    total_staffed_adult_icu_beds_7_day_sum icu_beds_used_7_day_sum  \
# 0                                      35                      32
# 1                                     308                     206
# 2                                       0                       0
# 3                                      12                      11
# 4                                     385                     580
#
#   staffed_adult_icu_bed_occupancy_7_day_sum  \
# 0                                        32
# 1                                       206
# 2                                         0
# 3                                        11
# 4                                       322
#
#    staffed_icu_adult_patients_con_and_sus_covid_7_day_sum  \
# 0                                                 20
# 1                                                 71
# 2                                                  0
# 3                                                  9
# 4                                                102
#
#    staffed_icu_adult_patients_con_covid_7_day_sum   index  cases_to_date  \
# 0                                              20   36036          45917
# 1                                              71  178047         173387
# 2                                               0  165921          10669
# 3                                               9  188051          33114
# 4                                             101  163069         150062
#
#    deaths_to_date
# 0             768
# 1            2631
# 2             161
# 3             787
# 4            2256
#
# [5 rows x 34 columns]
